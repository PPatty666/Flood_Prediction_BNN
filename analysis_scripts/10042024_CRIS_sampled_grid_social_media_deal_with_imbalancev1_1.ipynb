# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pickle

# %% [markdown]
# # Resample the imbalanced dataset

# %%
ds= pd.read_csv('prepared_ds/idalia1_prepared_ds_10082024.csv', index_col=0)

# %% [markdown]
# #Train, validation, test datasets and balanced mini batch

# %%
from sklearn.model_selection import train_test_split
# Use a utility from sklearn to split and shuffle your dataset.
other_df, test_df = train_test_split(ds, test_size=0.1, random_state=11)
train_df, val_df = train_test_split(other_df, test_size=0.2, random_state=23)

# %%
print(f'Average class probability in training set:   {train_df.flood_mark.mean():.4f}')
print(f'Average class probability in validation set: {val_df.flood_mark.mean():.4f}')
print(f'Average class probability in test set:       {test_df.flood_mark.mean():.4f}')

# %% [markdown]
# ## Techniques for neuro-net

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.models import load_model

import os
import tempfile

import matplotlib as mpl
import seaborn as sns

import sklearn
from sklearn.metrics import confusion_matrix

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, StandardScaler


def convert_float64(X):
    return X.astype(np.float64)

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
X_train = train_df[train_df.columns[:-1]].reset_index(drop=True)
y_train = train_df[train_df.columns[-1]].reset_index(drop=True)
X_val = val_df[val_df.columns[:-1]].reset_index(drop=True)
y_val = val_df[val_df.columns[-1]].reset_index(drop=True)
X_test = test_df[test_df.columns[:-1]].reset_index(drop=True)
y_test = test_df[test_df.columns[-1]].reset_index(drop=True)

# %%
numerical_columns = ["dem", "slope", "aspect", "curvx", "curvy", "fvc", "ndbi", "population", "dist2river", "rain", "x", "y"]
numerical_pipeline = make_pipeline(
    FunctionTransformer(func=convert_float64, validate=False), StandardScaler()
)

categorical_columns = ["lc_grp"]
categorical_pipeline = make_pipeline(
    # SimpleImputer(missing_values=-1, strategy="most_frequent"),
    OneHotEncoder(categories="auto"),
)

preprocessor = ColumnTransformer(
    [
        ("numerical_preprocessing", numerical_pipeline, numerical_columns),
        (
            "categorical_preprocessing",
            categorical_pipeline,
            categorical_columns,
        ),
    ],
    # remainder="drop",
)

# Create an environment variable to avoid using the GPU. This can be changed.
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
METRICS = [
      keras.metrics.BinaryCrossentropy(name='cross entropy'),  # same as model's loss
      keras.metrics.MeanSquaredError(name='Brier score'),
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'),
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_prc',
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %%
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='saved_model10082024/checkpoint_model_idalia1_10082024.keras',
    monitor='val_prc',  # Or any other metric you want to monitor
    mode='max',  # 'max' for accuracy, 'min' for loss
    save_best_only=True
)

# %% [markdown]
# ### Squential Model -- Can't apply monte carlo dropout with current syntax

# %%
from tensorflow.keras.layers import Activation, BatchNormalization, Dense, Dropout, InputLayer
from tensorflow.keras.models import Sequential


def make_model_deterministic(n_features):
    model = Sequential()
    model.add(InputLayer(input_shape=(n_features,)))
    model.add(Dropout(0.005))
    model.add(Dense(200, kernel_initializer="glorot_normal"))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    model.add(Dropout(0.5))
    model.add(Dense(100, kernel_initializer="glorot_normal", use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    model.add(Dropout(0.25))
    model.add(Dense(50, kernel_initializer="glorot_normal", use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    model.add(Dropout(0.15))
    model.add(Dense(25, kernel_initializer="glorot_normal", use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    model.add(Dropout(0.1))
    model.add(Dense(1, activation="sigmoid"))

    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=METRICS)

    return model

# %% [markdown]
# ### Functional API -- Monte Carlo droppout applied

# %%
def make_model(n_features):
    inputs = Input(shape=(n_features,))

    x = Dropout(0.05)(inputs, training=True)
    x = Dense(200, kernel_initializer="glorot_normal")(x)
    x = BatchNormalization()(x, training=False)
    x = Activation("relu")(x)
    x = Dropout(0.5)(x, training=False)
    x = Dense(100, kernel_initializer="glorot_normal", use_bias=False)(x)
    x = BatchNormalization()(x, training=False)
    x = Activation("relu")(x)
    x = Dropout(0.25)(x, training=False)
    x = Dense(50, kernel_initializer="glorot_normal", use_bias=False)(x)
    x = BatchNormalization()(x, training=False)
    x = Activation("relu")(x)
    x = Dropout(0.15)(x, training=False)
    x = Dense(25, kernel_initializer="glorot_normal", use_bias=False)(x)
    x = BatchNormalization()(x, training=False)
    x = Activation("relu")(x)
    x = Dropout(0.1)(x, training=False)

    outputs = Dense(1, activation="sigmoid")(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=METRICS)

    return model

# %% [markdown]
# ### Only use balanced mini batch because it has much higher recall and only train one model for now.

# %%
X_local_train = preprocessor.fit_transform(X_train)
y_local_train = y_train.values.ravel()
X_local_val = preprocessor.transform(X_val)
y_local_val = y_val.values.ravel()
X_local_test = preprocessor.transform(X_test)
y_local_test = y_test.values.ravel()

# %%
from imblearn.keras import BalancedBatchGenerator

# Expand targets to match model output
y_local_train_expanded = np.expand_dims(y_local_train, axis=-1)
y_local_val_expanded = np.expand_dims(y_local_val, axis=-1)

model = make_model(X_local_train.shape[1])
training_generator = BalancedBatchGenerator(
    X_local_train, y_local_train_expanded, batch_size=64, random_state=42
)

balancedbatch_history = model.fit(training_generator, epochs=100, verbose=1, callbacks=[checkpoint_callback], validation_data=(X_local_val, y_local_val_expanded))
balancedbatch_model = model
# Out:
# Epoch 1/100
# C:\Users\Mengj\anaconda3\envs\flood_prediction_social-media\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - Brier score: 0.1213 - accuracy: 0.8289 - auc: 0.9056 - cross entropy: 0.3859 - fn: 684.5551 - fp: 531.8071 - loss: 0.3859 - prc: 0.9028 - precision: 0.8435 - recall: 0.8066 - tn: 3556.3938 - tp: 3386.9922 - val_Brier score: 0.0620 - val_accuracy: 0.9130 - val_auc: 0.9803 - val_cross entropy: 0.2053 - val_fn: 74.0000 - val_fp: 2734.0000 - val_loss: 0.2053 - val_prc: 0.7656 - val_precision: 0.4237 - val_recall: 0.9645 - val_tn: 27450.0000 - val_tp: 2010.0000
# Epoch 2/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - Brier score: 0.0646 - accuracy: 0.9145 - auc: 0.9689 - cross entropy: 0.2218 - fn: 268.6339 - fp: 405.1299 - loss: 0.2218 - prc: 0.9631 - precision: 0.8992 - recall: 0.9316 - tn: 3678.8267 - tp: 3807.1575 - val_Brier score: 0.0503 - val_accuracy: 0.9310 - val_auc: 0.9841 - val_cross entropy: 0.1682 - val_fn: 48.0000 - val_fp: 2178.0000 - val_loss: 0.1682 - val_prc: 0.7918 - val_precision: 0.4832 - val_recall: 0.9770 - val_tn: 28006.0000 - val_tp: 2036.0000
# Epoch 3/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0545 - accuracy: 0.9271 - auc: 0.9764 - cross entropy: 0.1886 - fn: 206.9606 - fp: 373.2283 - loss: 0.1886 - prc: 0.9713 - precision: 0.9081 - recall: 0.9492 - tn: 3724.6890 - tp: 3854.8701 - val_Brier score: 0.0477 - val_accuracy: 0.9383 - val_auc: 0.9859 - val_cross entropy: 0.1581 - val_fn: 48.0000 - val_fp: 1942.0000 - val_loss: 0.1581 - val_prc: 0.8138 - val_precision: 0.5118 - val_recall: 0.9770 - val_tn: 28242.0000 - val_tp: 2036.0000
# Epoch 4/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0496 - accuracy: 0.9347 - auc: 0.9792 - cross entropy: 0.1758 - fn: 203.8228 - fp: 334.1614 - loss: 0.1758 - prc: 0.9748 - precision: 0.9235 - recall: 0.9494 - tn: 3722.7874 - tp: 3898.9763 - val_Brier score: 0.0427 - val_accuracy: 0.9463 - val_auc: 0.9861 - val_cross entropy: 0.1605 - val_fn: 49.0000 - val_fp: 1684.0000 - val_loss: 0.1605 - val_prc: 0.8182 - val_precision: 0.5472 - val_recall: 0.9765 - val_tn: 28500.0000 - val_tp: 2035.0000
# Epoch 5/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - Brier score: 0.0470 - accuracy: 0.9410 - auc: 0.9802 - cross entropy: 0.1707 - fn: 196.7244 - fp: 293.1850 - loss: 0.1707 - prc: 0.9763 - precision: 0.9335 - recall: 0.9498 - tn: 3789.4448 - tp: 3880.3938 - val_Brier score: 0.0462 - val_accuracy: 0.9398 - val_auc: 0.9886 - val_cross entropy: 0.1573 - val_fn: 33.0000 - val_fp: 1910.0000 - val_loss: 0.1573 - val_prc: 0.8462 - val_precision: 0.5178 - val_recall: 0.9842 - val_tn: 28274.0000 - val_tp: 2051.0000
# Epoch 6/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - Brier score: 0.0439 - accuracy: 0.9451 - auc: 0.9824 - cross entropy: 0.1578 - fn: 176.4764 - fp: 288.7677 - loss: 0.1578 - prc: 0.9795 - precision: 0.9334 - recall: 0.9588 - tn: 3781.8977 - tp: 3912.6062 - val_Brier score: 0.0414 - val_accuracy: 0.9464 - val_auc: 0.9892 - val_cross entropy: 0.1390 - val_fn: 36.0000 - val_fp: 1694.0000 - val_loss: 0.1390 - val_prc: 0.8586 - val_precision: 0.5473 - val_recall: 0.9827 - val_tn: 28490.0000 - val_tp: 2048.0000
# Epoch 7/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - Brier score: 0.0406 - accuracy: 0.9479 - auc: 0.9842 - cross entropy: 0.1472 - fn: 166.8898 - fp: 273.1417 - loss: 0.1472 - prc: 0.9816 - precision: 0.9370 - recall: 0.9605 - tn: 3808.2087 - tp: 3911.5078 - val_Brier score: 0.0395 - val_accuracy: 0.9497 - val_auc: 0.9891 - val_cross entropy: 0.1335 - val_fn: 40.0000 - val_fp: 1584.0000 - val_loss: 0.1335 - val_prc: 0.8716 - val_precision: 0.5634 - val_recall: 0.9808 - val_tn: 28600.0000 - val_tp: 2044.0000
# Epoch 8/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - Brier score: 0.0419 - accuracy: 0.9463 - auc: 0.9840 - cross entropy: 0.1513 - fn: 174.3110 - fp: 266.4961 - loss: 0.1513 - prc: 0.9813 - precision: 0.9371 - recall: 0.9565 - tn: 3811.4211 - tp: 3907.5198 - val_Brier score: 0.0383 - val_accuracy: 0.9496 - val_auc: 0.9920 - val_cross entropy: 0.1284 - val_fn: 32.0000 - val_fp: 1595.0000 - val_loss: 0.1284 - val_prc: 0.8806 - val_precision: 0.5627 - val_recall: 0.9846 - val_tn: 28589.0000 - val_tp: 2052.0000
# Epoch 9/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - Brier score: 0.0424 - accuracy: 0.9472 - auc: 0.9827 - cross entropy: 0.1547 - fn: 154.3150 - fp: 271.3937 - loss: 0.1547 - prc: 0.9774 - precision: 0.9329 - recall: 0.9630 - tn: 3814.3228 - tp: 3919.7166 - val_Brier score: 0.0380 - val_accuracy: 0.9493 - val_auc: 0.9919 - val_cross entropy: 0.1274 - val_fn: 45.0000 - val_fp: 1590.0000 - val_loss: 0.1274 - val_prc: 0.8939 - val_precision: 0.5619 - val_recall: 0.9784 - val_tn: 28594.0000 - val_tp: 2039.0000
# Epoch 10/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - Brier score: 0.0411 - accuracy: 0.9467 - auc: 0.9852 - cross entropy: 0.1460 - fn: 163.4921 - fp: 266.7559 - loss: 0.1460 - prc: 0.9824 - precision: 0.9354 - recall: 0.9587 - tn: 3839.9133 - tp: 3889.5867 - val_Brier score: 0.0392 - val_accuracy: 0.9488 - val_auc: 0.9929 - val_cross entropy: 0.1283 - val_fn: 34.0000 - val_fp: 1617.0000 - val_loss: 0.1283 - val_prc: 0.9063 - val_precision: 0.5590 - val_recall: 0.9837 - val_tn: 28567.0000 - val_tp: 2050.0000
# Epoch 11/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - Brier score: 0.0376 - accuracy: 0.9502 - auc: 0.9872 - cross entropy: 0.1357 - fn: 162.6024 - fp: 245.9685 - loss: 0.1357 - prc: 0.9848 - precision: 0.9407 - recall: 0.9605 - tn: 3827.5474 - tp: 3923.6299 - val_Brier score: 0.0298 - val_accuracy: 0.9597 - val_auc: 0.9931 - val_cross entropy: 0.0979 - val_fn: 57.0000 - val_fp: 1242.0000 - val_loss: 0.0979 - val_prc: 0.9124 - val_precision: 0.6201 - val_recall: 0.9726 - val_tn: 28942.0000 - val_tp: 2027.0000
# Epoch 12/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - Brier score: 0.0378 - accuracy: 0.9510 - auc: 0.9876 - cross entropy: 0.1336 - fn: 145.6142 - fp: 243.9213 - loss: 0.1336 - prc: 0.9852 - precision: 0.9413 - recall: 0.9633 - tn: 3805.7717 - tp: 3964.4409 - val_Brier score: 0.0311 - val_accuracy: 0.9570 - val_auc: 0.9941 - val_cross entropy: 0.1003 - val_fn: 48.0000 - val_fp: 1341.0000 - val_loss: 0.1003 - val_prc: 0.9258 - val_precision: 0.6029 - val_recall: 0.9770 - val_tn: 28843.0000 - val_tp: 2036.0000
# Epoch 13/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - Brier score: 0.0387 - accuracy: 0.9499 - auc: 0.9853 - cross entropy: 0.1409 - fn: 147.6811 - fp: 250.6220 - loss: 0.1409 - prc: 0.9813 - precision: 0.9380 - recall: 0.9631 - tn: 3844.9487 - tp: 3916.4961 - val_Brier score: 0.0304 - val_accuracy: 0.9572 - val_auc: 0.9942 - val_cross entropy: 0.0995 - val_fn: 29.0000 - val_fp: 1352.0000 - val_loss: 0.0995 - val_prc: 0.9229 - val_precision: 0.6032 - val_recall: 0.9861 - val_tn: 28832.0000 - val_tp: 2055.0000
# Epoch 14/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - Brier score: 0.0355 - accuracy: 0.9544 - auc: 0.9883 - cross entropy: 0.1280 - fn: 137.4646 - fp: 236.1575 - loss: 0.1280 - prc: 0.9856 - precision: 0.9434 - recall: 0.9669 - tn: 3830.1575 - tp: 3955.9685 - val_Brier score: 0.0317 - val_accuracy: 0.9563 - val_auc: 0.9942 - val_cross entropy: 0.1022 - val_fn: 32.0000 - val_fp: 1379.0000 - val_loss: 0.1022 - val_prc: 0.9244 - val_precision: 0.5981 - val_recall: 0.9846 - val_tn: 28805.0000 - val_tp: 2052.0000
# Epoch 15/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - Brier score: 0.0356 - accuracy: 0.9541 - auc: 0.9882 - cross entropy: 0.1291 - fn: 147.2126 - fp: 233.5000 - loss: 0.1291 - prc: 0.9859 - precision: 0.9457 - recall: 0.9632 - tn: 3856.8582 - tp: 3922.1772 - val_Brier score: 0.0302 - val_accuracy: 0.9580 - val_auc: 0.9944 - val_cross entropy: 0.1008 - val_fn: 30.0000 - val_fp: 1324.0000 - val_loss: 0.1008 - val_prc: 0.9180 - val_precision: 0.6081 - val_recall: 0.9856 - val_tn: 28860.0000 - val_tp: 2054.0000
# Epoch 16/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - Brier score: 0.0356 - accuracy: 0.9527 - auc: 0.9882 - cross entropy: 0.1283 - fn: 144.0472 - fp: 233.8110 - loss: 0.1283 - prc: 0.9845 - precision: 0.9412 - recall: 0.9640 - tn: 3855.5513 - tp: 3926.3386 - val_Brier score: 0.0296 - val_accuracy: 0.9587 - val_auc: 0.9945 - val_cross entropy: 0.0978 - val_fn: 33.0000 - val_fp: 1301.0000 - val_loss: 0.0978 - val_prc: 0.9259 - val_precision: 0.6119 - val_recall: 0.9842 - val_tn: 28883.0000 - val_tp: 2051.0000
# Epoch 17/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0356 - accuracy: 0.9527 - auc: 0.9886 - cross entropy: 0.1282 - fn: 152.2638 - fp: 227.8071 - loss: 0.1282 - prc: 0.9872 - precision: 0.9438 - recall: 0.9617 - tn: 3870.8188 - tp: 3908.8582 - val_Brier score: 0.0253 - val_accuracy: 0.9651 - val_auc: 0.9947 - val_cross entropy: 0.0874 - val_fn: 36.0000 - val_fp: 1089.0000 - val_loss: 0.0874 - val_prc: 0.9191 - val_precision: 0.6529 - val_recall: 0.9827 - val_tn: 29095.0000 - val_tp: 2048.0000
# Epoch 18/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0332 - accuracy: 0.9586 - auc: 0.9889 - cross entropy: 0.1227 - fn: 138.9528 - fp: 211.3858 - loss: 0.1227 - prc: 0.9862 - precision: 0.9522 - recall: 0.9661 - tn: 3854.4448 - tp: 3954.9646 - val_Brier score: 0.0273 - val_accuracy: 0.9629 - val_auc: 0.9955 - val_cross entropy: 0.0918 - val_fn: 27.0000 - val_fp: 1170.0000 - val_loss: 0.0918 - val_prc: 0.9335 - val_precision: 0.6374 - val_recall: 0.9870 - val_tn: 29014.0000 - val_tp: 2057.0000
# Epoch 19/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - Brier score: 0.0329 - accuracy: 0.9595 - auc: 0.9901 - cross entropy: 0.1199 - fn: 130.2047 - fp: 208.5079 - loss: 0.1199 - prc: 0.9894 - precision: 0.9509 - recall: 0.9693 - tn: 3866.1418 - tp: 3954.8938 - val_Brier score: 0.0250 - val_accuracy: 0.9658 - val_auc: 0.9963 - val_cross entropy: 0.0840 - val_fn: 29.0000 - val_fp: 1073.0000 - val_loss: 0.0840 - val_prc: 0.9461 - val_precision: 0.6570 - val_recall: 0.9861 - val_tn: 29111.0000 - val_tp: 2055.0000
# Epoch 20/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - Brier score: 0.0332 - accuracy: 0.9581 - auc: 0.9888 - cross entropy: 0.1217 - fn: 129.4213 - fp: 211.3701 - loss: 0.1217 - prc: 0.9862 - precision: 0.9484 - recall: 0.9692 - tn: 3854.9526 - tp: 3964.0039 - val_Brier score: 0.0216 - val_accuracy: 0.9697 - val_auc: 0.9962 - val_cross entropy: 0.0743 - val_fn: 37.0000 - val_fp: 940.0000 - val_loss: 0.0743 - val_prc: 0.9433 - val_precision: 0.6853 - val_recall: 0.9822 - val_tn: 29244.0000 - val_tp: 2047.0000
# Epoch 21/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - Brier score: 0.0328 - accuracy: 0.9570 - auc: 0.9903 - cross entropy: 0.1175 - fn: 139.4449 - fp: 219.3701 - loss: 0.1175 - prc: 0.9890 - precision: 0.9487 - recall: 0.9669 - tn: 3847.1023 - tp: 3953.8308 - val_Brier score: 0.0211 - val_accuracy: 0.9716 - val_auc: 0.9962 - val_cross entropy: 0.0713 - val_fn: 29.0000 - val_fp: 889.0000 - val_loss: 0.0713 - val_prc: 0.9409 - val_precision: 0.6980 - val_recall: 0.9861 - val_tn: 29295.0000 - val_tp: 2055.0000
# Epoch 22/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - Brier score: 0.0304 - accuracy: 0.9606 - auc: 0.9912 - cross entropy: 0.1106 - fn: 111.0827 - fp: 215.4843 - loss: 0.1106 - prc: 0.9890 - precision: 0.9494 - recall: 0.9735 - tn: 3856.0669 - tp: 3977.1143 - val_Brier score: 0.0214 - val_accuracy: 0.9717 - val_auc: 0.9964 - val_cross entropy: 0.0731 - val_fn: 20.0000 - val_fp: 894.0000 - val_loss: 0.0731 - val_prc: 0.9454 - val_precision: 0.6978 - val_recall: 0.9904 - val_tn: 29290.0000 - val_tp: 2064.0000
# Epoch 23/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0317 - accuracy: 0.9598 - auc: 0.9909 - cross entropy: 0.1137 - fn: 127.3583 - fp: 205.3622 - loss: 0.1137 - prc: 0.9893 - precision: 0.9510 - recall: 0.9695 - tn: 3879.7441 - tp: 3947.2834 - val_Brier score: 0.0192 - val_accuracy: 0.9748 - val_auc: 0.9965 - val_cross entropy: 0.0660 - val_fn: 34.0000 - val_fp: 780.0000 - val_loss: 0.0660 - val_prc: 0.9479 - val_precision: 0.7244 - val_recall: 0.9837 - val_tn: 29404.0000 - val_tp: 2050.0000
# Epoch 24/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - Brier score: 0.0328 - accuracy: 0.9566 - auc: 0.9902 - cross entropy: 0.1173 - fn: 122.8307 - fp: 217.2323 - loss: 0.1173 - prc: 0.9889 - precision: 0.9461 - recall: 0.9685 - tn: 3865.9292 - tp: 3953.7559 - val_Brier score: 0.0223 - val_accuracy: 0.9705 - val_auc: 0.9967 - val_cross entropy: 0.0766 - val_fn: 21.0000 - val_fp: 930.0000 - val_loss: 0.0766 - val_prc: 0.9479 - val_precision: 0.6893 - val_recall: 0.9899 - val_tn: 29254.0000 - val_tp: 2063.0000
# Epoch 25/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - Brier score: 0.0297 - accuracy: 0.9626 - auc: 0.9913 - cross entropy: 0.1094 - fn: 121.4921 - fp: 186.8189 - loss: 0.1094 - prc: 0.9892 - precision: 0.9550 - recall: 0.9703 - tn: 3912.5630 - tp: 3938.8740 - val_Brier score: 0.0192 - val_accuracy: 0.9733 - val_auc: 0.9966 - val_cross entropy: 0.0659 - val_fn: 34.0000 - val_fp: 826.0000 - val_loss: 0.0659 - val_prc: 0.9489 - val_precision: 0.7128 - val_recall: 0.9837 - val_tn: 29358.0000 - val_tp: 2050.0000
# Epoch 26/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0291 - accuracy: 0.9632 - auc: 0.9919 - cross entropy: 0.1063 - fn: 111.7520 - fp: 186.4488 - loss: 0.1063 - prc: 0.9904 - precision: 0.9546 - recall: 0.9725 - tn: 3881.0117 - tp: 3980.5354 - val_Brier score: 0.0196 - val_accuracy: 0.9738 - val_auc: 0.9970 - val_cross entropy: 0.0672 - val_fn: 22.0000 - val_fp: 824.0000 - val_loss: 0.0672 - val_prc: 0.9548 - val_precision: 0.7145 - val_recall: 0.9894 - val_tn: 29360.0000 - val_tp: 2062.0000
# Epoch 27/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - Brier score: 0.0297 - accuracy: 0.9615 - auc: 0.9920 - cross entropy: 0.1066 - fn: 122.2874 - fp: 197.2008 - loss: 0.1066 - prc: 0.9908 - precision: 0.9533 - recall: 0.9710 - tn: 3865.6968 - tp: 3974.5630 - val_Brier score: 0.0204 - val_accuracy: 0.9726 - val_auc: 0.9972 - val_cross entropy: 0.0690 - val_fn: 24.0000 - val_fp: 860.0000 - val_loss: 0.0690 - val_prc: 0.9563 - val_precision: 0.7055 - val_recall: 0.9885 - val_tn: 29324.0000 - val_tp: 2060.0000
# Epoch 28/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - Brier score: 0.0280 - accuracy: 0.9643 - auc: 0.9923 - cross entropy: 0.1022 - fn: 113.2559 - fp: 179.4291 - loss: 0.1022 - prc: 0.9903 - precision: 0.9579 - recall: 0.9728 - tn: 3837.2637 - tp: 4029.7993 - val_Brier score: 0.0192 - val_accuracy: 0.9736 - val_auc: 0.9972 - val_cross entropy: 0.0668 - val_fn: 26.0000 - val_fp: 825.0000 - val_loss: 0.0668 - val_prc: 0.9518 - val_precision: 0.7138 - val_recall: 0.9875 - val_tn: 29359.0000 - val_tp: 2058.0000
# Epoch 29/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0273 - accuracy: 0.9648 - auc: 0.9919 - cross entropy: 0.1016 - fn: 120.6339 - fp: 179.8228 - loss: 0.1016 - prc: 0.9904 - precision: 0.9584 - recall: 0.9720 - tn: 3892.5039 - tp: 3966.7874 - val_Brier score: 0.0198 - val_accuracy: 0.9742 - val_auc: 0.9976 - val_cross entropy: 0.0685 - val_fn: 26.0000 - val_fp: 805.0000 - val_loss: 0.0685 - val_prc: 0.9633 - val_precision: 0.7188 - val_recall: 0.9875 - val_tn: 29379.0000 - val_tp: 2058.0000
# Epoch 30/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - Brier score: 0.0281 - accuracy: 0.9630 - auc: 0.9929 - cross entropy: 0.1016 - fn: 115.3504 - fp: 185.8622 - loss: 0.1016 - prc: 0.9919 - precision: 0.9554 - recall: 0.9718 - tn: 3878.3032 - tp: 3980.2322 - val_Brier score: 0.0175 - val_accuracy: 0.9761 - val_auc: 0.9980 - val_cross entropy: 0.0581 - val_fn: 22.0000 - val_fp: 748.0000 - val_loss: 0.0581 - val_prc: 0.9731 - val_precision: 0.7338 - val_recall: 0.9894 - val_tn: 29436.0000 - val_tp: 2062.0000
# Epoch 31/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - Brier score: 0.0281 - accuracy: 0.9614 - auc: 0.9928 - cross entropy: 0.1008 - fn: 121.9882 - fp: 192.5709 - loss: 0.1008 - prc: 0.9917 - precision: 0.9524 - recall: 0.9704 - tn: 3910.4448 - tp: 3934.7441 - val_Brier score: 0.0200 - val_accuracy: 0.9742 - val_auc: 0.9976 - val_cross entropy: 0.0691 - val_fn: 15.0000 - val_fp: 817.0000 - val_loss: 0.0691 - val_prc: 0.9647 - val_precision: 0.7169 - val_recall: 0.9928 - val_tn: 29367.0000 - val_tp: 2069.0000
# Epoch 32/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0276 - accuracy: 0.9649 - auc: 0.9923 - cross entropy: 0.1010 - fn: 113.3307 - fp: 171.6890 - loss: 0.1010 - prc: 0.9907 - precision: 0.9590 - recall: 0.9717 - tn: 3913.6104 - tp: 3961.1182 - val_Brier score: 0.0184 - val_accuracy: 0.9743 - val_auc: 0.9980 - val_cross entropy: 0.0614 - val_fn: 22.0000 - val_fp: 806.0000 - val_loss: 0.0614 - val_prc: 0.9701 - val_precision: 0.7190 - val_recall: 0.9894 - val_tn: 29378.0000 - val_tp: 2062.0000
# Epoch 33/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0280 - accuracy: 0.9632 - auc: 0.9934 - cross entropy: 0.0995 - fn: 120.1850 - fp: 185.2165 - loss: 0.0995 - prc: 0.9926 - precision: 0.9554 - recall: 0.9718 - tn: 3897.8662 - tp: 3956.4802 - val_Brier score: 0.0189 - val_accuracy: 0.9745 - val_auc: 0.9980 - val_cross entropy: 0.0650 - val_fn: 14.0000 - val_fp: 809.0000 - val_loss: 0.0650 - val_prc: 0.9688 - val_precision: 0.7190 - val_recall: 0.9933 - val_tn: 29375.0000 - val_tp: 2070.0000
# Epoch 34/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - Brier score: 0.0269 - accuracy: 0.9652 - auc: 0.9933 - cross entropy: 0.0975 - fn: 118.1024 - fp: 171.2835 - loss: 0.0975 - prc: 0.9926 - precision: 0.9588 - recall: 0.9721 - tn: 3907.8818 - tp: 3962.4802 - val_Brier score: 0.0173 - val_accuracy: 0.9758 - val_auc: 0.9983 - val_cross entropy: 0.0586 - val_fn: 16.0000 - val_fp: 765.0000 - val_loss: 0.0586 - val_prc: 0.9745 - val_precision: 0.7300 - val_recall: 0.9923 - val_tn: 29419.0000 - val_tp: 2068.0000
# Epoch 35/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0261 - accuracy: 0.9663 - auc: 0.9934 - cross entropy: 0.0957 - fn: 114.9882 - fp: 161.9921 - loss: 0.0957 - prc: 0.9923 - precision: 0.9622 - recall: 0.9716 - tn: 3893.0828 - tp: 3989.6851 - val_Brier score: 0.0173 - val_accuracy: 0.9764 - val_auc: 0.9978 - val_cross entropy: 0.0603 - val_fn: 19.0000 - val_fp: 743.0000 - val_loss: 0.0603 - val_prc: 0.9644 - val_precision: 0.7354 - val_recall: 0.9909 - val_tn: 29441.0000 - val_tp: 2065.0000
# Epoch 36/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - Brier score: 0.0264 - accuracy: 0.9666 - auc: 0.9929 - cross entropy: 0.0989 - fn: 123.2441 - fp: 158.8543 - loss: 0.0989 - prc: 0.9915 - precision: 0.9632 - recall: 0.9705 - tn: 3917.8425 - tp: 3959.8071 - val_Brier score: 0.0163 - val_accuracy: 0.9775 - val_auc: 0.9985 - val_cross entropy: 0.0568 - val_fn: 13.0000 - val_fp: 714.0000 - val_loss: 0.0568 - val_prc: 0.9778 - val_precision: 0.7436 - val_recall: 0.9938 - val_tn: 29470.0000 - val_tp: 2071.0000
# Epoch 37/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - Brier score: 0.0279 - accuracy: 0.9632 - auc: 0.9929 - cross entropy: 0.1004 - fn: 110.3780 - fp: 176.6181 - loss: 0.1004 - prc: 0.9920 - precision: 0.9555 - recall: 0.9712 - tn: 3906.9685 - tp: 3965.7834 - val_Brier score: 0.0175 - val_accuracy: 0.9766 - val_auc: 0.9976 - val_cross entropy: 0.0647 - val_fn: 12.0000 - val_fp: 742.0000 - val_loss: 0.0647 - val_prc: 0.9527 - val_precision: 0.7363 - val_recall: 0.9942 - val_tn: 29442.0000 - val_tp: 2072.0000
# Epoch 38/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - Brier score: 0.0273 - accuracy: 0.9655 - auc: 0.9933 - cross entropy: 0.0982 - fn: 122.1339 - fp: 156.6890 - loss: 0.0982 - prc: 0.9924 - precision: 0.9630 - recall: 0.9689 - tn: 3913.0198 - tp: 3967.9055 - val_Brier score: 0.0169 - val_accuracy: 0.9768 - val_auc: 0.9980 - val_cross entropy: 0.0598 - val_fn: 18.0000 - val_fp: 730.0000 - val_loss: 0.0598 - val_prc: 0.9628 - val_precision: 0.7389 - val_recall: 0.9914 - val_tn: 29454.0000 - val_tp: 2066.0000
# Epoch 39/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - Brier score: 0.0271 - accuracy: 0.9646 - auc: 0.9935 - cross entropy: 0.0970 - fn: 110.8583 - fp: 168.8346 - loss: 0.0970 - prc: 0.9920 - precision: 0.9580 - recall: 0.9715 - tn: 3937.6104 - tp: 3942.4448 - val_Brier score: 0.0163 - val_accuracy: 0.9784 - val_auc: 0.9980 - val_cross entropy: 0.0583 - val_fn: 15.0000 - val_fp: 682.0000 - val_loss: 0.0583 - val_prc: 0.9620 - val_precision: 0.7521 - val_recall: 0.9928 - val_tn: 29502.0000 - val_tp: 2069.0000
# Epoch 40/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0264 - accuracy: 0.9651 - auc: 0.9943 - cross entropy: 0.0930 - fn: 110.0866 - fp: 169.6811 - loss: 0.0930 - prc: 0.9941 - precision: 0.9593 - recall: 0.9722 - tn: 3906.1221 - tp: 3973.8582 - val_Brier score: 0.0157 - val_accuracy: 0.9781 - val_auc: 0.9979 - val_cross entropy: 0.0552 - val_fn: 16.0000 - val_fp: 690.0000 - val_loss: 0.0552 - val_prc: 0.9618 - val_precision: 0.7498 - val_recall: 0.9923 - val_tn: 29494.0000 - val_tp: 2068.0000
# Epoch 41/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - Brier score: 0.0245 - accuracy: 0.9675 - auc: 0.9946 - cross entropy: 0.0880 - fn: 108.9213 - fp: 166.9803 - loss: 0.0880 - prc: 0.9935 - precision: 0.9611 - recall: 0.9747 - tn: 3901.0789 - tp: 3982.7678 - val_Brier score: 0.0160 - val_accuracy: 0.9779 - val_auc: 0.9983 - val_cross entropy: 0.0555 - val_fn: 12.0000 - val_fp: 702.0000 - val_loss: 0.0555 - val_prc: 0.9691 - val_precision: 0.7469 - val_recall: 0.9942 - val_tn: 29482.0000 - val_tp: 2072.0000
# Epoch 42/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - Brier score: 0.0228 - accuracy: 0.9713 - auc: 0.9942 - cross entropy: 0.0861 - fn: 94.4646 - fp: 156.9764 - loss: 0.0861 - prc: 0.9930 - precision: 0.9640 - recall: 0.9795 - tn: 3913.9763 - tp: 3994.3308 - val_Brier score: 0.0153 - val_accuracy: 0.9785 - val_auc: 0.9981 - val_cross entropy: 0.0542 - val_fn: 15.0000 - val_fp: 680.0000 - val_loss: 0.0542 - val_prc: 0.9653 - val_precision: 0.7526 - val_recall: 0.9928 - val_tn: 29504.0000 - val_tp: 2069.0000
# Epoch 43/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - Brier score: 0.0236 - accuracy: 0.9694 - auc: 0.9938 - cross entropy: 0.0888 - fn: 111.6378 - fp: 153.5315 - loss: 0.0888 - prc: 0.9928 - precision: 0.9649 - recall: 0.9745 - tn: 3921.6575 - tp: 3972.9211 - val_Brier score: 0.0155 - val_accuracy: 0.9780 - val_auc: 0.9985 - val_cross entropy: 0.0539 - val_fn: 13.0000 - val_fp: 698.0000 - val_loss: 0.0539 - val_prc: 0.9725 - val_precision: 0.7479 - val_recall: 0.9938 - val_tn: 29486.0000 - val_tp: 2071.0000
# Epoch 44/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0243 - accuracy: 0.9690 - auc: 0.9942 - cross entropy: 0.0891 - fn: 94.3071 - fp: 153.6890 - loss: 0.0891 - prc: 0.9930 - precision: 0.9619 - recall: 0.9766 - tn: 3928.8542 - tp: 3982.8977 - val_Brier score: 0.0144 - val_accuracy: 0.9805 - val_auc: 0.9985 - val_cross entropy: 0.0501 - val_fn: 15.0000 - val_fp: 613.0000 - val_loss: 0.0501 - val_prc: 0.9726 - val_precision: 0.7714 - val_recall: 0.9928 - val_tn: 29571.0000 - val_tp: 2069.0000
# Epoch 45/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - Brier score: 0.0247 - accuracy: 0.9678 - auc: 0.9946 - cross entropy: 0.0875 - fn: 98.3661 - fp: 165.1299 - loss: 0.0875 - prc: 0.9940 - precision: 0.9593 - recall: 0.9769 - tn: 3934.9526 - tp: 3961.2993 - val_Brier score: 0.0168 - val_accuracy: 0.9775 - val_auc: 0.9984 - val_cross entropy: 0.0589 - val_fn: 12.0000 - val_fp: 714.0000 - val_loss: 0.0589 - val_prc: 0.9723 - val_precision: 0.7437 - val_recall: 0.9942 - val_tn: 29470.0000 - val_tp: 2072.0000
# Epoch 46/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - Brier score: 0.0244 - accuracy: 0.9689 - auc: 0.9937 - cross entropy: 0.0903 - fn: 104.1575 - fp: 150.5984 - loss: 0.0903 - prc: 0.9921 - precision: 0.9638 - recall: 0.9749 - tn: 3922.5078 - tp: 3982.4841 - val_Brier score: 0.0167 - val_accuracy: 0.9769 - val_auc: 0.9983 - val_cross entropy: 0.0580 - val_fn: 11.0000 - val_fp: 733.0000 - val_loss: 0.0580 - val_prc: 0.9648 - val_precision: 0.7388 - val_recall: 0.9947 - val_tn: 29451.0000 - val_tp: 2073.0000
# Epoch 47/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0230 - accuracy: 0.9702 - auc: 0.9951 - cross entropy: 0.0830 - fn: 95.8425 - fp: 147.0709 - loss: 0.0830 - prc: 0.9943 - precision: 0.9636 - recall: 0.9771 - tn: 3927.7874 - tp: 3989.0474 - val_Brier score: 0.0158 - val_accuracy: 0.9784 - val_auc: 0.9987 - val_cross entropy: 0.0561 - val_fn: 10.0000 - val_fp: 687.0000 - val_loss: 0.0561 - val_prc: 0.9731 - val_precision: 0.7512 - val_recall: 0.9952 - val_tn: 29497.0000 - val_tp: 2074.0000
# Epoch 48/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0230 - accuracy: 0.9706 - auc: 0.9950 - cross entropy: 0.0832 - fn: 98.2835 - fp: 145.5827 - loss: 0.0832 - prc: 0.9949 - precision: 0.9642 - recall: 0.9780 - tn: 3905.9568 - tp: 4009.9253 - val_Brier score: 0.0107 - val_accuracy: 0.9848 - val_auc: 0.9989 - val_cross entropy: 0.0378 - val_fn: 24.0000 - val_fp: 465.0000 - val_loss: 0.0378 - val_prc: 0.9841 - val_precision: 0.8158 - val_recall: 0.9885 - val_tn: 29719.0000 - val_tp: 2060.0000
# Epoch 49/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - Brier score: 0.0234 - accuracy: 0.9705 - auc: 0.9947 - cross entropy: 0.0860 - fn: 104.8031 - fp: 133.6654 - loss: 0.0860 - prc: 0.9939 - precision: 0.9669 - recall: 0.9746 - tn: 3954.9922 - tp: 3966.2874 - val_Brier score: 0.0141 - val_accuracy: 0.9806 - val_auc: 0.9990 - val_cross entropy: 0.0477 - val_fn: 15.0000 - val_fp: 612.0000 - val_loss: 0.0477 - val_prc: 0.9842 - val_precision: 0.7717 - val_recall: 0.9928 - val_tn: 29572.0000 - val_tp: 2069.0000
# Epoch 50/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - Brier score: 0.0237 - accuracy: 0.9678 - auc: 0.9946 - cross entropy: 0.0856 - fn: 113.5866 - fp: 149.5709 - loss: 0.0856 - prc: 0.9932 - precision: 0.9631 - recall: 0.9729 - tn: 3917.1851 - tp: 3979.4055 - val_Brier score: 0.0142 - val_accuracy: 0.9803 - val_auc: 0.9988 - val_cross entropy: 0.0487 - val_fn: 14.0000 - val_fp: 623.0000 - val_loss: 0.0487 - val_prc: 0.9802 - val_precision: 0.7687 - val_recall: 0.9933 - val_tn: 29561.0000 - val_tp: 2070.0000
# Epoch 51/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - Brier score: 0.0233 - accuracy: 0.9698 - auc: 0.9941 - cross entropy: 0.0877 - fn: 107.6299 - fp: 142.2638 - loss: 0.0877 - prc: 0.9931 - precision: 0.9653 - recall: 0.9745 - tn: 3946.4292 - tp: 3963.4253 - val_Brier score: 0.0147 - val_accuracy: 0.9786 - val_auc: 0.9989 - val_cross entropy: 0.0491 - val_fn: 14.0000 - val_fp: 675.0000 - val_loss: 0.0491 - val_prc: 0.9839 - val_precision: 0.7541 - val_recall: 0.9933 - val_tn: 29509.0000 - val_tp: 2070.0000
# Epoch 52/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - Brier score: 0.0260 - accuracy: 0.9663 - auc: 0.9942 - cross entropy: 0.0932 - fn: 112.9528 - fp: 159.9567 - loss: 0.0932 - prc: 0.9932 - precision: 0.9608 - recall: 0.9725 - tn: 3911.4094 - tp: 3975.4292 - val_Brier score: 0.0133 - val_accuracy: 0.9808 - val_auc: 0.9987 - val_cross entropy: 0.0463 - val_fn: 12.0000 - val_fp: 607.0000 - val_loss: 0.0463 - val_prc: 0.9760 - val_precision: 0.7734 - val_recall: 0.9942 - val_tn: 29577.0000 - val_tp: 2072.0000
# Epoch 53/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - Brier score: 0.0211 - accuracy: 0.9729 - auc: 0.9953 - cross entropy: 0.0784 - fn: 96.1260 - fp: 129.2992 - loss: 0.0784 - prc: 0.9944 - precision: 0.9704 - recall: 0.9758 - tn: 3957.9802 - tp: 3976.3425 - val_Brier score: 0.0129 - val_accuracy: 0.9830 - val_auc: 0.9984 - val_cross entropy: 0.0492 - val_fn: 12.0000 - val_fp: 537.0000 - val_loss: 0.0492 - val_prc: 0.9676 - val_precision: 0.7942 - val_recall: 0.9942 - val_tn: 29647.0000 - val_tp: 2072.0000
# Epoch 54/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0252 - accuracy: 0.9684 - auc: 0.9935 - cross entropy: 0.0918 - fn: 111.6929 - fp: 136.8386 - loss: 0.0918 - prc: 0.9924 - precision: 0.9664 - recall: 0.9710 - tn: 3931.2402 - tp: 3979.9763 - val_Brier score: 0.0135 - val_accuracy: 0.9820 - val_auc: 0.9989 - val_cross entropy: 0.0486 - val_fn: 10.0000 - val_fp: 572.0000 - val_loss: 0.0486 - val_prc: 0.9785 - val_precision: 0.7838 - val_recall: 0.9952 - val_tn: 29612.0000 - val_tp: 2074.0000
# Epoch 55/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0210 - accuracy: 0.9716 - auc: 0.9958 - cross entropy: 0.0758 - fn: 97.0906 - fp: 133.3937 - loss: 0.0758 - prc: 0.9952 - precision: 0.9669 - recall: 0.9762 - tn: 3954.0513 - tp: 3975.2126 - val_Brier score: 0.0115 - val_accuracy: 0.9839 - val_auc: 0.9989 - val_cross entropy: 0.0401 - val_fn: 12.0000 - val_fp: 508.0000 - val_loss: 0.0401 - val_prc: 0.9826 - val_precision: 0.8031 - val_recall: 0.9942 - val_tn: 29676.0000 - val_tp: 2072.0000
# Epoch 56/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0234 - accuracy: 0.9700 - auc: 0.9942 - cross entropy: 0.0878 - fn: 104.8819 - fp: 135.3150 - loss: 0.0878 - prc: 0.9932 - precision: 0.9660 - recall: 0.9740 - tn: 3950.3308 - tp: 3969.2205 - val_Brier score: 0.0113 - val_accuracy: 0.9843 - val_auc: 0.9989 - val_cross entropy: 0.0411 - val_fn: 11.0000 - val_fp: 494.0000 - val_loss: 0.0411 - val_prc: 0.9800 - val_precision: 0.8076 - val_recall: 0.9947 - val_tn: 29690.0000 - val_tp: 2073.0000
# Epoch 57/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0236 - accuracy: 0.9684 - auc: 0.9948 - cross entropy: 0.0846 - fn: 115.6024 - fp: 144.5709 - loss: 0.0846 - prc: 0.9939 - precision: 0.9651 - recall: 0.9720 - tn: 3940.9526 - tp: 3958.6221 - val_Brier score: 0.0125 - val_accuracy: 0.9823 - val_auc: 0.9986 - val_cross entropy: 0.0448 - val_fn: 13.0000 - val_fp: 558.0000 - val_loss: 0.0448 - val_prc: 0.9737 - val_precision: 0.7878 - val_recall: 0.9938 - val_tn: 29626.0000 - val_tp: 2071.0000
# Epoch 58/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0222 - accuracy: 0.9706 - auc: 0.9954 - cross entropy: 0.0801 - fn: 102.5945 - fp: 132.0984 - loss: 0.0801 - prc: 0.9946 - precision: 0.9685 - recall: 0.9725 - tn: 3957.0945 - tp: 3967.9607 - val_Brier score: 0.0139 - val_accuracy: 0.9801 - val_auc: 0.9988 - val_cross entropy: 0.0491 - val_fn: 14.0000 - val_fp: 627.0000 - val_loss: 0.0491 - val_prc: 0.9768 - val_precision: 0.7675 - val_recall: 0.9933 - val_tn: 29557.0000 - val_tp: 2070.0000
# Epoch 59/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0219 - accuracy: 0.9714 - auc: 0.9952 - cross entropy: 0.0804 - fn: 98.9291 - fp: 133.5905 - loss: 0.0804 - prc: 0.9942 - precision: 0.9681 - recall: 0.9747 - tn: 3944.3267 - tp: 3982.9016 - val_Brier score: 0.0116 - val_accuracy: 0.9841 - val_auc: 0.9987 - val_cross entropy: 0.0425 - val_fn: 12.0000 - val_fp: 501.0000 - val_loss: 0.0425 - val_prc: 0.9762 - val_precision: 0.8053 - val_recall: 0.9942 - val_tn: 29683.0000 - val_tp: 2072.0000
# Epoch 60/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0203 - accuracy: 0.9749 - auc: 0.9963 - cross entropy: 0.0733 - fn: 90.7362 - fp: 126.3976 - loss: 0.0733 - prc: 0.9961 - precision: 0.9711 - recall: 0.9786 - tn: 3967.6536 - tp: 3974.9607 - val_Brier score: 0.0129 - val_accuracy: 0.9825 - val_auc: 0.9985 - val_cross entropy: 0.0487 - val_fn: 9.0000 - val_fp: 555.0000 - val_loss: 0.0487 - val_prc: 0.9662 - val_precision: 0.7890 - val_recall: 0.9957 - val_tn: 29629.0000 - val_tp: 2075.0000
# Epoch 61/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0218 - accuracy: 0.9695 - auc: 0.9956 - cross entropy: 0.0783 - fn: 110.5827 - fp: 126.1339 - loss: 0.0783 - prc: 0.9952 - precision: 0.9683 - recall: 0.9703 - tn: 3973.2913 - tp: 3949.7402 - val_Brier score: 0.0123 - val_accuracy: 0.9830 - val_auc: 0.9986 - val_cross entropy: 0.0466 - val_fn: 12.0000 - val_fp: 535.0000 - val_loss: 0.0466 - val_prc: 0.9697 - val_precision: 0.7948 - val_recall: 0.9942 - val_tn: 29649.0000 - val_tp: 2072.0000
# Epoch 62/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0218 - accuracy: 0.9731 - auc: 0.9945 - cross entropy: 0.0817 - fn: 94.1299 - fp: 134.5039 - loss: 0.0817 - prc: 0.9931 - precision: 0.9692 - recall: 0.9775 - tn: 3933.6536 - tp: 3997.4607 - val_Brier score: 0.0126 - val_accuracy: 0.9827 - val_auc: 0.9987 - val_cross entropy: 0.0464 - val_fn: 11.0000 - val_fp: 546.0000 - val_loss: 0.0464 - val_prc: 0.9739 - val_precision: 0.7915 - val_recall: 0.9947 - val_tn: 29638.0000 - val_tp: 2073.0000
# Epoch 63/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0202 - accuracy: 0.9740 - auc: 0.9956 - cross entropy: 0.0755 - fn: 92.7992 - fp: 124.5472 - loss: 0.0755 - prc: 0.9950 - precision: 0.9713 - recall: 0.9768 - tn: 3960.9646 - tp: 3981.4370 - val_Brier score: 0.0110 - val_accuracy: 0.9843 - val_auc: 0.9989 - val_cross entropy: 0.0390 - val_fn: 16.0000 - val_fp: 490.0000 - val_loss: 0.0390 - val_prc: 0.9795 - val_precision: 0.8084 - val_recall: 0.9923 - val_tn: 29694.0000 - val_tp: 2068.0000
# Epoch 64/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0209 - accuracy: 0.9736 - auc: 0.9955 - cross entropy: 0.0767 - fn: 92.4331 - fp: 129.2953 - loss: 0.0767 - prc: 0.9940 - precision: 0.9693 - recall: 0.9780 - tn: 3945.7441 - tp: 3992.2756 - val_Brier score: 0.0115 - val_accuracy: 0.9850 - val_auc: 0.9989 - val_cross entropy: 0.0415 - val_fn: 12.0000 - val_fp: 472.0000 - val_loss: 0.0415 - val_prc: 0.9786 - val_precision: 0.8145 - val_recall: 0.9942 - val_tn: 29712.0000 - val_tp: 2072.0000
# Epoch 65/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0227 - accuracy: 0.9698 - auc: 0.9955 - cross entropy: 0.0813 - fn: 106.0984 - fp: 133.7677 - loss: 0.0813 - prc: 0.9952 - precision: 0.9673 - recall: 0.9724 - tn: 3956.3032 - tp: 3963.5789 - val_Brier score: 0.0114 - val_accuracy: 0.9841 - val_auc: 0.9989 - val_cross entropy: 0.0403 - val_fn: 12.0000 - val_fp: 500.0000 - val_loss: 0.0403 - val_prc: 0.9808 - val_precision: 0.8056 - val_recall: 0.9942 - val_tn: 29684.0000 - val_tp: 2072.0000
# Epoch 66/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0223 - accuracy: 0.9714 - auc: 0.9953 - cross entropy: 0.0806 - fn: 91.2913 - fp: 138.7126 - loss: 0.0806 - prc: 0.9946 - precision: 0.9665 - recall: 0.9769 - tn: 3928.4331 - tp: 4001.3110 - val_Brier score: 0.0112 - val_accuracy: 0.9837 - val_auc: 0.9990 - val_cross entropy: 0.0384 - val_fn: 12.0000 - val_fp: 513.0000 - val_loss: 0.0384 - val_prc: 0.9816 - val_precision: 0.8015 - val_recall: 0.9942 - val_tn: 29671.0000 - val_tp: 2072.0000
# Epoch 67/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0215 - accuracy: 0.9723 - auc: 0.9952 - cross entropy: 0.0793 - fn: 85.8386 - fp: 140.8898 - loss: 0.0793 - prc: 0.9945 - precision: 0.9655 - recall: 0.9799 - tn: 3933.7717 - tp: 3999.2480 - val_Brier score: 0.0110 - val_accuracy: 0.9850 - val_auc: 0.9991 - val_cross entropy: 0.0398 - val_fn: 11.0000 - val_fp: 472.0000 - val_loss: 0.0398 - val_prc: 0.9818 - val_precision: 0.8145 - val_recall: 0.9947 - val_tn: 29712.0000 - val_tp: 2073.0000
# Epoch 68/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0222 - accuracy: 0.9717 - auc: 0.9953 - cross entropy: 0.0804 - fn: 96.6299 - fp: 132.5000 - loss: 0.0804 - prc: 0.9946 - precision: 0.9679 - recall: 0.9761 - tn: 3919.5432 - tp: 4011.0747 - val_Brier score: 0.0119 - val_accuracy: 0.9834 - val_auc: 0.9992 - val_cross entropy: 0.0414 - val_fn: 12.0000 - val_fp: 523.0000 - val_loss: 0.0414 - val_prc: 0.9863 - val_precision: 0.7985 - val_recall: 0.9942 - val_tn: 29661.0000 - val_tp: 2072.0000
# Epoch 69/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - Brier score: 0.0201 - accuracy: 0.9737 - auc: 0.9961 - cross entropy: 0.0726 - fn: 90.0984 - fp: 123.9882 - loss: 0.0726 - prc: 0.9955 - precision: 0.9694 - recall: 0.9784 - tn: 3958.2993 - tp: 3987.3623 - val_Brier score: 0.0114 - val_accuracy: 0.9835 - val_auc: 0.9992 - val_cross entropy: 0.0399 - val_fn: 11.0000 - val_fp: 523.0000 - val_loss: 0.0399 - val_prc: 0.9861 - val_precision: 0.7985 - val_recall: 0.9947 - val_tn: 29661.0000 - val_tp: 2073.0000
# Epoch 70/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0200 - accuracy: 0.9713 - auc: 0.9967 - cross entropy: 0.0696 - fn: 100.5827 - fp: 126.4252 - loss: 0.0696 - prc: 0.9965 - precision: 0.9691 - recall: 0.9739 - tn: 3970.6023 - tp: 3962.1377 - val_Brier score: 0.0114 - val_accuracy: 0.9841 - val_auc: 0.9991 - val_cross entropy: 0.0410 - val_fn: 9.0000 - val_fp: 505.0000 - val_loss: 0.0410 - val_prc: 0.9816 - val_precision: 0.8043 - val_recall: 0.9957 - val_tn: 29679.0000 - val_tp: 2075.0000
# Epoch 71/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0191 - accuracy: 0.9749 - auc: 0.9965 - cross entropy: 0.0691 - fn: 84.5433 - fp: 121.9685 - loss: 0.0691 - prc: 0.9963 - precision: 0.9708 - recall: 0.9798 - tn: 3926.4607 - tp: 4026.7756 - val_Brier score: 0.0112 - val_accuracy: 0.9843 - val_auc: 0.9990 - val_cross entropy: 0.0410 - val_fn: 8.0000 - val_fp: 498.0000 - val_loss: 0.0410 - val_prc: 0.9794 - val_precision: 0.8065 - val_recall: 0.9962 - val_tn: 29686.0000 - val_tp: 2076.0000
# Epoch 72/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0206 - accuracy: 0.9740 - auc: 0.9958 - cross entropy: 0.0756 - fn: 98.6024 - fp: 115.5236 - loss: 0.0756 - prc: 0.9955 - precision: 0.9731 - recall: 0.9753 - tn: 3969.8542 - tp: 3975.7678 - val_Brier score: 0.0102 - val_accuracy: 0.9861 - val_auc: 0.9992 - val_cross entropy: 0.0369 - val_fn: 6.0000 - val_fp: 443.0000 - val_loss: 0.0369 - val_prc: 0.9821 - val_precision: 0.8243 - val_recall: 0.9971 - val_tn: 29741.0000 - val_tp: 2078.0000
# Epoch 73/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0200 - accuracy: 0.9738 - auc: 0.9962 - cross entropy: 0.0722 - fn: 85.2756 - fp: 129.9843 - loss: 0.0722 - prc: 0.9956 - precision: 0.9676 - recall: 0.9806 - tn: 3931.1575 - tp: 4013.3308 - val_Brier score: 0.0089 - val_accuracy: 0.9873 - val_auc: 0.9992 - val_cross entropy: 0.0326 - val_fn: 9.0000 - val_fp: 402.0000 - val_loss: 0.0326 - val_prc: 0.9835 - val_precision: 0.8377 - val_recall: 0.9957 - val_tn: 29782.0000 - val_tp: 2075.0000
# Epoch 74/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0180 - accuracy: 0.9768 - auc: 0.9965 - cross entropy: 0.0670 - fn: 79.2323 - fp: 121.4055 - loss: 0.0670 - prc: 0.9957 - precision: 0.9722 - recall: 0.9820 - tn: 3940.8425 - tp: 4018.2678 - val_Brier score: 0.0104 - val_accuracy: 0.9866 - val_auc: 0.9990 - val_cross entropy: 0.0411 - val_fn: 6.0000 - val_fp: 427.0000 - val_loss: 0.0411 - val_prc: 0.9768 - val_precision: 0.8295 - val_recall: 0.9971 - val_tn: 29757.0000 - val_tp: 2078.0000
# Epoch 75/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0188 - accuracy: 0.9754 - auc: 0.9965 - cross entropy: 0.0683 - fn: 89.7480 - fp: 116.8583 - loss: 0.0683 - prc: 0.9959 - precision: 0.9735 - recall: 0.9777 - tn: 3946.6104 - tp: 4006.5315 - val_Brier score: 0.0095 - val_accuracy: 0.9875 - val_auc: 0.9990 - val_cross entropy: 0.0360 - val_fn: 10.0000 - val_fp: 394.0000 - val_loss: 0.0360 - val_prc: 0.9786 - val_precision: 0.8404 - val_recall: 0.9952 - val_tn: 29790.0000 - val_tp: 2074.0000
# Epoch 76/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0199 - accuracy: 0.9742 - auc: 0.9959 - cross entropy: 0.0732 - fn: 87.5906 - fp: 120.0000 - loss: 0.0732 - prc: 0.9952 - precision: 0.9711 - recall: 0.9776 - tn: 3952.3582 - tp: 3999.7993 - val_Brier score: 0.0089 - val_accuracy: 0.9870 - val_auc: 0.9992 - val_cross entropy: 0.0328 - val_fn: 12.0000 - val_fp: 406.0000 - val_loss: 0.0328 - val_prc: 0.9826 - val_precision: 0.8362 - val_recall: 0.9942 - val_tn: 29778.0000 - val_tp: 2072.0000
# Epoch 77/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0189 - accuracy: 0.9765 - auc: 0.9961 - cross entropy: 0.0695 - fn: 81.6890 - fp: 111.2047 - loss: 0.0695 - prc: 0.9954 - precision: 0.9734 - recall: 0.9795 - tn: 3974.4055 - tp: 3992.4487 - val_Brier score: 0.0097 - val_accuracy: 0.9867 - val_auc: 0.9993 - val_cross entropy: 0.0341 - val_fn: 4.0000 - val_fp: 426.0000 - val_loss: 0.0341 - val_prc: 0.9861 - val_precision: 0.8300 - val_recall: 0.9981 - val_tn: 29758.0000 - val_tp: 2080.0000
# Epoch 78/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0198 - accuracy: 0.9744 - auc: 0.9966 - cross entropy: 0.0702 - fn: 88.8976 - fp: 121.0197 - loss: 0.0702 - prc: 0.9963 - precision: 0.9710 - recall: 0.9783 - tn: 3951.4133 - tp: 3998.4172 - val_Brier score: 0.0104 - val_accuracy: 0.9859 - val_auc: 0.9991 - val_cross entropy: 0.0365 - val_fn: 11.0000 - val_fp: 444.0000 - val_loss: 0.0365 - val_prc: 0.9845 - val_precision: 0.8236 - val_recall: 0.9947 - val_tn: 29740.0000 - val_tp: 2073.0000
# Epoch 79/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - Brier score: 0.0203 - accuracy: 0.9725 - auc: 0.9959 - cross entropy: 0.0731 - fn: 92.7047 - fp: 129.0276 - loss: 0.0731 - prc: 0.9948 - precision: 0.9686 - recall: 0.9766 - tn: 3960.8977 - tp: 3977.1182 - val_Brier score: 0.0106 - val_accuracy: 0.9858 - val_auc: 0.9990 - val_cross entropy: 0.0383 - val_fn: 5.0000 - val_fp: 453.0000 - val_loss: 0.0383 - val_prc: 0.9779 - val_precision: 0.8211 - val_recall: 0.9976 - val_tn: 29731.0000 - val_tp: 2079.0000
# Epoch 80/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0192 - accuracy: 0.9754 - auc: 0.9956 - cross entropy: 0.0719 - fn: 81.0984 - fp: 120.8386 - loss: 0.0719 - prc: 0.9940 - precision: 0.9698 - recall: 0.9810 - tn: 3968.2598 - tp: 3989.5513 - val_Brier score: 0.0100 - val_accuracy: 0.9856 - val_auc: 0.9992 - val_cross entropy: 0.0359 - val_fn: 8.0000 - val_fp: 457.0000 - val_loss: 0.0359 - val_prc: 0.9846 - val_precision: 0.8196 - val_recall: 0.9962 - val_tn: 29727.0000 - val_tp: 2076.0000
# Epoch 81/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0204 - accuracy: 0.9733 - auc: 0.9956 - cross entropy: 0.0751 - fn: 84.8543 - fp: 130.0197 - loss: 0.0751 - prc: 0.9948 - precision: 0.9687 - recall: 0.9786 - tn: 3935.2322 - tp: 4009.6418 - val_Brier score: 0.0096 - val_accuracy: 0.9871 - val_auc: 0.9992 - val_cross entropy: 0.0360 - val_fn: 8.0000 - val_fp: 408.0000 - val_loss: 0.0360 - val_prc: 0.9825 - val_precision: 0.8357 - val_recall: 0.9962 - val_tn: 29776.0000 - val_tp: 2076.0000
# Epoch 82/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0210 - accuracy: 0.9736 - auc: 0.9951 - cross entropy: 0.0783 - fn: 91.9528 - fp: 121.7717 - loss: 0.0783 - prc: 0.9939 - precision: 0.9691 - recall: 0.9783 - tn: 3943.7007 - tp: 4002.3228 - val_Brier score: 0.0094 - val_accuracy: 0.9877 - val_auc: 0.9992 - val_cross entropy: 0.0357 - val_fn: 12.0000 - val_fp: 386.0000 - val_loss: 0.0357 - val_prc: 0.9841 - val_precision: 0.8430 - val_recall: 0.9942 - val_tn: 29798.0000 - val_tp: 2072.0000
# Epoch 83/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0176 - accuracy: 0.9763 - auc: 0.9970 - cross entropy: 0.0641 - fn: 86.6929 - fp: 108.8504 - loss: 0.0641 - prc: 0.9967 - precision: 0.9738 - recall: 0.9787 - tn: 3985.6221 - tp: 3978.5828 - val_Brier score: 0.0080 - val_accuracy: 0.9890 - val_auc: 0.9994 - val_cross entropy: 0.0294 - val_fn: 10.0000 - val_fp: 344.0000 - val_loss: 0.0294 - val_prc: 0.9887 - val_precision: 0.8577 - val_recall: 0.9952 - val_tn: 29840.0000 - val_tp: 2074.0000
# Epoch 84/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - Brier score: 0.0172 - accuracy: 0.9782 - auc: 0.9971 - cross entropy: 0.0629 - fn: 75.3858 - fp: 108.8031 - loss: 0.0629 - prc: 0.9968 - precision: 0.9750 - recall: 0.9819 - tn: 3971.2717 - tp: 4004.2874 - val_Brier score: 0.0078 - val_accuracy: 0.9898 - val_auc: 0.9991 - val_cross entropy: 0.0294 - val_fn: 9.0000 - val_fp: 320.0000 - val_loss: 0.0294 - val_prc: 0.9786 - val_precision: 0.8664 - val_recall: 0.9957 - val_tn: 29864.0000 - val_tp: 2075.0000
# Epoch 85/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0173 - accuracy: 0.9776 - auc: 0.9971 - cross entropy: 0.0631 - fn: 78.5669 - fp: 104.7677 - loss: 0.0631 - prc: 0.9967 - precision: 0.9747 - recall: 0.9809 - tn: 3954.3938 - tp: 4022.0198 - val_Brier score: 0.0093 - val_accuracy: 0.9877 - val_auc: 0.9993 - val_cross entropy: 0.0350 - val_fn: 6.0000 - val_fp: 391.0000 - val_loss: 0.0350 - val_prc: 0.9855 - val_precision: 0.8416 - val_recall: 0.9971 - val_tn: 29793.0000 - val_tp: 2078.0000
# Epoch 86/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0185 - accuracy: 0.9773 - auc: 0.9955 - cross entropy: 0.0713 - fn: 77.3110 - fp: 115.5787 - loss: 0.0713 - prc: 0.9945 - precision: 0.9726 - recall: 0.9823 - tn: 3974.8425 - tp: 3992.0159 - val_Brier score: 0.0080 - val_accuracy: 0.9891 - val_auc: 0.9993 - val_cross entropy: 0.0308 - val_fn: 4.0000 - val_fp: 349.0000 - val_loss: 0.0308 - val_prc: 0.9846 - val_precision: 0.8563 - val_recall: 0.9981 - val_tn: 29835.0000 - val_tp: 2080.0000
# Epoch 87/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0166 - accuracy: 0.9794 - auc: 0.9967 - cross entropy: 0.0634 - fn: 71.4685 - fp: 97.4055 - loss: 0.0634 - prc: 0.9966 - precision: 0.9755 - recall: 0.9836 - tn: 3990.9331 - tp: 3999.9409 - val_Brier score: 0.0085 - val_accuracy: 0.9887 - val_auc: 0.9993 - val_cross entropy: 0.0334 - val_fn: 3.0000 - val_fp: 363.0000 - val_loss: 0.0334 - val_prc: 0.9830 - val_precision: 0.8515 - val_recall: 0.9986 - val_tn: 29821.0000 - val_tp: 2081.0000
# Epoch 88/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0189 - accuracy: 0.9757 - auc: 0.9957 - cross entropy: 0.0721 - fn: 81.6024 - fp: 110.3819 - loss: 0.0721 - prc: 0.9952 - precision: 0.9719 - recall: 0.9799 - tn: 3941.8896 - tp: 4025.8740 - val_Brier score: 0.0081 - val_accuracy: 0.9894 - val_auc: 0.9990 - val_cross entropy: 0.0331 - val_fn: 9.0000 - val_fp: 334.0000 - val_loss: 0.0331 - val_prc: 0.9771 - val_precision: 0.8614 - val_recall: 0.9957 - val_tn: 29850.0000 - val_tp: 2075.0000
# Epoch 89/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0170 - accuracy: 0.9784 - auc: 0.9964 - cross entropy: 0.0655 - fn: 86.8661 - fp: 95.0669 - loss: 0.0655 - prc: 0.9959 - precision: 0.9781 - recall: 0.9784 - tn: 4004.0867 - tp: 3973.7283 - val_Brier score: 0.0079 - val_accuracy: 0.9901 - val_auc: 0.9991 - val_cross entropy: 0.0318 - val_fn: 12.0000 - val_fp: 306.0000 - val_loss: 0.0318 - val_prc: 0.9816 - val_precision: 0.8713 - val_recall: 0.9942 - val_tn: 29878.0000 - val_tp: 2072.0000
# Epoch 90/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - Brier score: 0.0190 - accuracy: 0.9749 - auc: 0.9963 - cross entropy: 0.0705 - fn: 96.5748 - fp: 107.5630 - loss: 0.0705 - prc: 0.9957 - precision: 0.9734 - recall: 0.9762 - tn: 3992.4883 - tp: 3963.1221 - val_Brier score: 0.0081 - val_accuracy: 0.9892 - val_auc: 0.9990 - val_cross entropy: 0.0322 - val_fn: 4.0000 - val_fp: 343.0000 - val_loss: 0.0322 - val_prc: 0.9770 - val_precision: 0.8584 - val_recall: 0.9981 - val_tn: 29841.0000 - val_tp: 2080.0000
# Epoch 91/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0174 - accuracy: 0.9777 - auc: 0.9964 - cross entropy: 0.0651 - fn: 79.5039 - fp: 103.6339 - loss: 0.0651 - prc: 0.9957 - precision: 0.9747 - recall: 0.9812 - tn: 3956.9370 - tp: 4019.6733 - val_Brier score: 0.0079 - val_accuracy: 0.9901 - val_auc: 0.9991 - val_cross entropy: 0.0313 - val_fn: 8.0000 - val_fp: 310.0000 - val_loss: 0.0313 - val_prc: 0.9804 - val_precision: 0.8701 - val_recall: 0.9962 - val_tn: 29874.0000 - val_tp: 2076.0000
# Epoch 92/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0181 - accuracy: 0.9764 - auc: 0.9969 - cross entropy: 0.0654 - fn: 88.5000 - fp: 104.3661 - loss: 0.0654 - prc: 0.9967 - precision: 0.9754 - recall: 0.9772 - tn: 4000.9253 - tp: 3965.9568 - val_Brier score: 0.0076 - val_accuracy: 0.9910 - val_auc: 0.9991 - val_cross entropy: 0.0309 - val_fn: 6.0000 - val_fp: 285.0000 - val_loss: 0.0309 - val_prc: 0.9782 - val_precision: 0.8794 - val_recall: 0.9971 - val_tn: 29899.0000 - val_tp: 2078.0000
# Epoch 93/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0172 - accuracy: 0.9776 - auc: 0.9971 - cross entropy: 0.0621 - fn: 84.3071 - fp: 105.5433 - loss: 0.0621 - prc: 0.9965 - precision: 0.9746 - recall: 0.9807 - tn: 3958.3149 - tp: 4011.5828 - val_Brier score: 0.0067 - val_accuracy: 0.9923 - val_auc: 0.9992 - val_cross entropy: 0.0267 - val_fn: 14.0000 - val_fp: 235.0000 - val_loss: 0.0267 - val_prc: 0.9835 - val_precision: 0.8980 - val_recall: 0.9933 - val_tn: 29949.0000 - val_tp: 2070.0000
# Epoch 94/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0184 - accuracy: 0.9754 - auc: 0.9965 - cross entropy: 0.0668 - fn: 87.3898 - fp: 110.9488 - loss: 0.0668 - prc: 0.9956 - precision: 0.9723 - recall: 0.9790 - tn: 3947.5039 - tp: 4013.9055 - val_Brier score: 0.0087 - val_accuracy: 0.9887 - val_auc: 0.9991 - val_cross entropy: 0.0347 - val_fn: 6.0000 - val_fp: 358.0000 - val_loss: 0.0347 - val_prc: 0.9803 - val_precision: 0.8530 - val_recall: 0.9971 - val_tn: 29826.0000 - val_tp: 2078.0000
# Epoch 95/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0191 - accuracy: 0.9758 - auc: 0.9969 - cross entropy: 0.0679 - fn: 87.2244 - fp: 106.5945 - loss: 0.0679 - prc: 0.9968 - precision: 0.9742 - recall: 0.9777 - tn: 3966.1458 - tp: 3999.7834 - val_Brier score: 0.0077 - val_accuracy: 0.9907 - val_auc: 0.9992 - val_cross entropy: 0.0307 - val_fn: 6.0000 - val_fp: 293.0000 - val_loss: 0.0307 - val_prc: 0.9811 - val_precision: 0.8764 - val_recall: 0.9971 - val_tn: 29891.0000 - val_tp: 2078.0000
# Epoch 96/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - Brier score: 0.0194 - accuracy: 0.9753 - auc: 0.9964 - cross entropy: 0.0704 - fn: 81.4409 - fp: 116.6102 - loss: 0.0704 - prc: 0.9959 - precision: 0.9709 - recall: 0.9805 - tn: 3934.8267 - tp: 4026.8701 - val_Brier score: 0.0085 - val_accuracy: 0.9890 - val_auc: 0.9993 - val_cross entropy: 0.0319 - val_fn: 5.0000 - val_fp: 350.0000 - val_loss: 0.0319 - val_prc: 0.9857 - val_precision: 0.8559 - val_recall: 0.9976 - val_tn: 29834.0000 - val_tp: 2079.0000
# Epoch 97/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - Brier score: 0.0169 - accuracy: 0.9778 - auc: 0.9973 - cross entropy: 0.0607 - fn: 78.6417 - fp: 104.2165 - loss: 0.0607 - prc: 0.9971 - precision: 0.9756 - recall: 0.9803 - tn: 3965.4724 - tp: 4011.4172 - val_Brier score: 0.0075 - val_accuracy: 0.9904 - val_auc: 0.9993 - val_cross entropy: 0.0291 - val_fn: 7.0000 - val_fp: 304.0000 - val_loss: 0.0291 - val_prc: 0.9837 - val_precision: 0.8723 - val_recall: 0.9966 - val_tn: 29880.0000 - val_tp: 2077.0000
# Epoch 98/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - Brier score: 0.0185 - accuracy: 0.9770 - auc: 0.9957 - cross entropy: 0.0698 - fn: 73.3661 - fp: 111.4173 - loss: 0.0698 - prc: 0.9944 - precision: 0.9718 - recall: 0.9823 - tn: 3983.4055 - tp: 3991.5591 - val_Brier score: 0.0078 - val_accuracy: 0.9900 - val_auc: 0.9992 - val_cross entropy: 0.0301 - val_fn: 8.0000 - val_fp: 315.0000 - val_loss: 0.0301 - val_prc: 0.9838 - val_precision: 0.8683 - val_recall: 0.9962 - val_tn: 29869.0000 - val_tp: 2076.0000
# Epoch 99/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - Brier score: 0.0188 - accuracy: 0.9754 - auc: 0.9969 - cross entropy: 0.0669 - fn: 83.0315 - fp: 109.8307 - loss: 0.0669 - prc: 0.9964 - precision: 0.9714 - recall: 0.9793 - tn: 3977.5432 - tp: 3989.3425 - val_Brier score: 0.0086 - val_accuracy: 0.9891 - val_auc: 0.9991 - val_cross entropy: 0.0342 - val_fn: 5.0000 - val_fp: 348.0000 - val_loss: 0.0342 - val_prc: 0.9797 - val_precision: 0.8566 - val_recall: 0.9976 - val_tn: 29836.0000 - val_tp: 2079.0000
# Epoch 100/100
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - Brier score: 0.0149 - accuracy: 0.9802 - auc: 0.9977 - cross entropy: 0.0543 - fn: 70.1732 - fp: 99.1575 - loss: 0.0543 - prc: 0.9974 - precision: 0.9764 - recall: 0.9840 - tn: 3985.6653 - tp: 4004.7520 - val_Brier score: 0.0072 - val_accuracy: 0.9914 - val_auc: 0.9991 - val_cross entropy: 0.0303 - val_fn: 4.0000 - val_fp: 274.0000 - val_loss: 0.0303 - val_prc: 0.9782 - val_precision: 0.8836 - val_recall: 0.9981 - val_tn: 29910.0000 - val_tp: 2080.0000

# %%
# For model/code testing and maintanence purpose
from imblearn.keras import BalancedBatchGenerator

# Expand targets to match model output
y_local_train_expanded = np.expand_dims(y_local_train, axis=-1)
y_local_val_expanded = np.expand_dims(y_local_val, axis=-1)

model = make_model(X_local_train.shape[1])
training_generator = BalancedBatchGenerator(
    X_local_train, y_local_train_expanded, batch_size=64, random_state=42
)

balancedbatch_history = model.fit(training_generator, epochs=2, verbose=1, validation_data=(X_local_val, y_local_val_expanded))
balancedbatch_model = model
# Out:
# Epoch 1/2
# C:\Users\Mengj\anaconda3\envs\flood_prediction_social-media\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - Brier score: 0.1290 - accuracy: 0.8128 - auc: 0.8923 - cross entropy: 0.4045 - fn: 763.1910 - fp: 680.0955 - loss: 0.4045 - prc: 0.8917 - precision: 0.8181 - recall: 0.8126 - tn: 3916.4895 - tp: 3820.1165 - val_Brier score: 0.0481 - val_accuracy: 0.9340 - val_auc: 0.9804 - val_cross entropy: 0.1688 - val_fn: 121.0000 - val_fp: 2008.0000 - val_loss: 0.1688 - val_prc: 0.7576 - val_precision: 0.4943 - val_recall: 0.9419 - val_tn: 28176.0000 - val_tp: 1963.0000
# Epoch 2/2
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - Brier score: 0.0631 - accuracy: 0.9132 - auc: 0.9702 - cross entropy: 0.2183 - fn: 290.6092 - fp: 418.4092 - loss: 0.2183 - prc: 0.9630 - precision: 0.9031 - recall: 0.9279 - tn: 3756.6987 - tp: 3938.1448 - val_Brier score: 0.0530 - val_accuracy: 0.9281 - val_auc: 0.9849 - val_cross entropy: 0.1808 - val_fn: 46.0000 - val_fp: 2273.0000 - val_loss: 0.1808 - val_prc: 0.8038 - val_precision: 0.4727 - val_recall: 0.9779 - val_tn: 27911.0000 - val_tp: 2038.0000

# %%
# best_model = keras.models.load_model('saved_model10082024/checkpoint_model_idalia1_10082024.keras')

# %%
# best_model.save('saved_model10082024/checkpoint_model_idalia1_10082024.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#You can save and load your own trained model
best_model_h5 = load_model('saved_model10082024/checkpoint_model_idalia1_10082024.h5')
best_model_h5.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 15)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 15)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 200)                 │           3,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 200)                 │             800 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 200)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 200)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 100)                 │          20,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 100)                 │             400 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 50)                  │           5,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 50)                  │             200 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 25)                  │           1,250 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 25)                  │             100 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 25)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 25)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,978 (121.01 KB)
#  Trainable params: 30,226 (118.07 KB)
#  Non-trainable params: 750 (2.93 KB)
#  Optimizer params: 2 (12.00 B)

# %%
def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()
    plt.show()

# %%
plot_metrics(balancedbatch_history)

# %%
balancedbatch_model.load_weights('saved_model10082024/checkpoint_model_idalia1_10082024.keras')

# %%
balanced_model_predv1 = best_model_h5.predict(X_local_test, batch_size=64, verbose=0)
balanced_model_predv1

# %%
balanced_model_predv2 = balancedbatch_model.predict(X_local_test, batch_size=64, verbose=0)
balanced_model_predv2

# %%
#test code .prediction (no MC Dropout)
sum(balanced_model_predv1 == balanced_model_predv2) == len(balanced_model_predv1)

# %%
#apply MC Dropout
balancedbatch_model(X_local_test)
# Out:
# <tf.Tensor: shape=(16134, 1), dtype=float32, numpy=
# array([[8.5460215e-06],
#        [8.6376276e-03],
#        [2.8776241e-04],
#        ...,
#        [6.8050984e-05],
#        [4.9580699e-03],
#        [9.9984556e-01]], dtype=float32)>

# %%
#Draw samples
y_hat_mc = np.array([balancedbatch_model(X_local_test) for _ in range(2000)])

# %%
def plot_cm(labels, predictions, threshold=0.5):
  cm = confusion_matrix(labels, predictions > threshold)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(threshold))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Non Flooded Points Detected (True Negatives): ', cm[0][0])
  print('Non Flooded Points Incorrectly Detected (False Positives): ', cm[0][1])
  print('Flooded Points Missed (False Negatives): ', cm[1][0])
  print('Flooded Points Detected (True Positives): ', cm[1][1])
  print('Total Flooded Points: ', np.sum(cm[1]))

# %%
plot_cm(y_local_test, np.mean(y_hat_mc, axis=0).squeeze())

# %%
np.std(y_hat_mc, axis=0).squeeze().mean()

# %% [markdown]
# plot the uncertainty information of the sampled flood risk distribution: standard deviation, the 3rd central moment, the 4th central moment

# %%
def plot_uncertainty_moments(
    y_true, y_hat_mc,
    threshold=0.5,
    bins=30,
    share_bins=True,
    is_logits=False,
    show_confusion=True,
    figsize=(10, 8)
):
    """
    Plot MC predictive std, 3rd central moment (mu3), and 4th central moment (mu4)
    split by confusion outcomes (TP/TN/FP/FN). Skips mean histogram.

    Parameters
    ----------
    y_true : array-like, shape (N,)
        Ground truth labels {0,1}.
    y_hat_mc : array-like, shape (S,N) or (N,S) or (S,N,1)
        MC samples of predicted probabilities (or logits if is_logits=True).
    threshold : float
        Decision threshold applied to MC mean.
    bins : int
        Number of bins (or used to make shared bins).
    share_bins : bool
        If True, use the same bin edges across TP/TN/FP/FN for each metric panel.
    is_logits : bool
        If True, apply sigmoid to y_hat_mc before stats.
    show_confusion : bool
        If True, prints confusion matrix summary.
    figsize : tuple
        Figure size for each 2×2 panel.
    """

    y_true = np.asarray(y_true).astype(int).ravel()
    y_hat_mc = np.asarray(y_hat_mc)

    # --- shape handling: (S,N,1)->(S,N), ensure 2D ---
    if y_hat_mc.ndim == 3 and y_hat_mc.shape[-1] == 1:
        y_hat_mc = y_hat_mc.squeeze(-1)

    if y_hat_mc.ndim != 2:
        raise ValueError(f"Expected 2D MC array after squeezing, got {y_hat_mc.shape}")

    S, M = y_hat_mc.shape
    N = y_true.size

    # Ensure y_hat_mc is (S, N)
    if M == N:
        pass
    elif S == N and M != N:
        y_hat_mc = y_hat_mc.T
        S, M = y_hat_mc.shape
    else:
        raise ValueError(f"Cannot align shapes: y_hat_mc={y_hat_mc.shape}, y_true={y_true.shape}")

    # logits -> probabilities
    if is_logits:
        from scipy.special import expit
        y_hat_mc = expit(y_hat_mc)

    # clamp
    y_hat_mc = np.clip(y_hat_mc, 0.0, 1.0)

    # --- stats per point ---
    p_mean = y_hat_mc.mean(axis=0)          # (N,)
    p_std  = y_hat_mc.std(axis=0)           # (N,)

    diff = y_hat_mc - p_mean                # broadcast (S,N) - (N,)
    mu3  = np.mean(diff**3, axis=0)         # (N,)
    mu4  = np.mean(diff**4, axis=0)         # (N,)

    # --- hard pred from MC mean ---
    y_pred = (p_mean > threshold).astype(int)

    # confusion masks
    TP = (y_true == 1) & (y_pred == 1)
    TN = (y_true == 0) & (y_pred == 0)
    FP = (y_true == 0) & (y_pred == 1)
    FN = (y_true == 1) & (y_pred == 0)

    groups = {
        "True Positives":  TP,
        "True Negatives":  TN,
        "False Positives": FP,
        "False Negatives": FN,
    }

    stds = {k: p_std[m] for k, m in groups.items()}
    m3s  = {k: mu3[m]  for k, m in groups.items()}
    m4s  = {k: mu4[m]  for k, m in groups.items()}

    if show_confusion:
        cm = confusion_matrix(y_true, y_pred)
        print(f"Confusion Matrix @ {threshold:.2f}:\n{cm}")
        print("TP={}, TN={}, FP={}, FN={}".format(
            stds["True Positives"].size,
            stds["True Negatives"].size,
            stds["False Positives"].size,
            stds["False Negatives"].size
        ))

    # --- helpers for shared bins ---
    def make_shared_bin_edges(values_dict):
        finite_vals = np.concatenate([v[np.isfinite(v)] for v in values_dict.values() if v.size])
        if finite_vals.size == 0:
            return np.linspace(0, 1e-6, bins + 1)
        vmin, vmax = float(np.min(finite_vals)), float(np.max(finite_vals))
        if vmin == vmax:
            vmin -= 1e-6
            vmax += 1e-6
        return np.linspace(vmin, vmax, bins + 1)

    def plot_panel(values_dict, xlabel, title):
        bin_edges = make_shared_bin_edges(values_dict) if share_bins else None

        fig, axes = plt.subplots(2, 2, figsize=figsize)
        axes = axes.ravel()

        for ax, (label, arr) in zip(axes, values_dict.items()):
            if arr.size == 0:
                ax.text(0.5, 0.5, "No samples", ha="center", va="center", transform=ax.transAxes)
            else:
                ax.hist(arr, bins=(bin_edges if share_bins else bins), edgecolor="black")
            ax.set_title(f"{label} (n={arr.size})")
            ax.set_xlabel(xlabel)
            ax.set_ylabel("Count")

        fig.suptitle(f"{title} by outcome @ threshold={threshold:.2f}")
        fig.tight_layout()
        plt.show()
        return fig

    # --- plot the three panels ---
    fig_std = plot_panel(stds, r"Predictive $\sigma$ (MC)", r"MC Predictive Uncertainty ($\sigma$)")
    fig_m3  = plot_panel(m3s,  r"3rd central moment ($\mu_3$)", r"MC 3rd Central Moment ($\mu_3$)")
    fig_m4  = plot_panel(m4s,  r"4th central moment ($\mu_4$)", r"MC 4th Central Moment ($\mu_4$))")

    # return arrays + figs for reuse
    out = {
        "p_mean": p_mean,
        "p_std": p_std,
        "mu3": mu3,
        "mu4": mu4,
        "y_pred": y_pred,
        "groups": groups,
        "stds_by_outcome": stds,
        "mu3_by_outcome": m3s,
        "mu4_by_outcome": m4s,
        "figures": (fig_std, fig_m3, fig_m4),
    }
    return out

# %%
out = plot_uncertainty_moments(
    y_local_test,
    y_hat_mc,
    threshold=0.5,
    bins=30,
    share_bins=True,
    is_logits=False
)

# %% [markdown]
# # Make predictions using MC model

# %% [markdown]
# ### Prepare dataset for prediction:
#
# Most of the input layer were downloaded or calculated from google earth engine.
#
# DEM datasource in the shared drive was resampled to 10 meters.

# %%
# cols = ["coordinates", "id", "elev", "flabel", "slope", "aspect", "curvex", "curvey", "fvc", "ndbi", "landcover", "rain", "population", "dist2river"]
df_predv1 = gpd.read_file("/content/drive/MyDrive/social_media_based_model/model_test/07152024/grid30m_inspection07152024.shp")
# df.columns = cols
df_predv1.dropna().head()
# Out:
#        dem    slope     aspect  curvature_  curvatur_1  simple_esa      fvc  \
# 0  4.43957  0.30876   85.20870     0.17586    -0.01197         2.0  0.47273
# 1  4.36276  1.27461  177.35248    -0.21330     0.07581         1.0  0.43633
# 2  4.25769  0.29232  174.67653     0.29209    -0.44655         1.0  0.72432
# 3  4.02727  0.53895   93.78531    -0.21337     0.07409         2.0  0.10234
# 4  4.33231  0.47361  298.55835    -0.07294     0.31866         2.0  0.32793
#
#       ndbi  population  dist2river  rain_idali                    geometry
# 0 -0.01085     2.36280        34.0     33.2329  POINT (-82.77158 27.92079)
# 1 -0.09858    23.43978        34.0     33.2329  POINT (-82.77158 27.92049)
# 2 -0.10734    23.43978        34.0     33.2329  POINT (-82.77158 27.92019)
# 3  0.07016    18.90984        34.0     33.2329  POINT (-82.77158 27.91989)
# 4 -0.03505   142.95651        34.0     33.2329  POINT (-82.77158 27.91959)

# %%
df_predv1 = df_predv1[df_predv1.simple_esa.isin([0., 1., 2.])].dropna().reset_index(drop=True)
df_predv1.shape
# Out:
# (310738, 12)

# %%
coord_list_predv1 = [(x,y) for x,y in zip(df_predv1['geometry'].x , df_predv1['geometry'].y)]

# %%
df_predv1['x'] = pd.DataFrame(coord_list_predv1)[0]
df_predv1['y'] = pd.DataFrame(coord_list_predv1)[1]

# %%
df_predv1 = df_predv1[["dem", "slope", "aspect", "curvature_", "curvatur_1", "simple_esa", "fvc", "ndbi", "population", "dist2river", "rain_idali", "x", "y"]]
cols_predv1 = ["dem", "slope", "aspect", "curvx", "curvy", "lc_grp", "fvc", "ndbi", "population", "dist2river", "rain", "x", "y"]
df_predv1.columns = cols_predv1
df_predv1.head()
# Out:
#        dem    slope     aspect    curvx    curvy  lc_grp      fvc     ndbi  \
# 0  4.43957  0.30876   85.20870  0.17586 -0.01197     2.0  0.47273 -0.01085
# 1  4.36276  1.27461  177.35248 -0.21330  0.07581     1.0  0.43633 -0.09858
# 2  4.25769  0.29232  174.67653  0.29209 -0.44655     1.0  0.72432 -0.10734
# 3  4.02727  0.53895   93.78531 -0.21337  0.07409     2.0  0.10234  0.07016
# 4  4.33231  0.47361  298.55835 -0.07294  0.31866     2.0  0.32793 -0.03505
#
#    population  dist2river     rain          x          y
# 0     2.36280        34.0  33.2329 -82.771576  27.920787
# 1    23.43978        34.0  33.2329 -82.771576  27.920487
# 2    23.43978        34.0  33.2329 -82.771576  27.920187
# 3    18.90984        34.0  33.2329 -82.771576  27.919887
# 4   142.95651        34.0  33.2329 -82.771576  27.919587

# %%
df_predv1.lc_grp = pd.Categorical(df_predv1.lc_grp)

# %%
df_predv1.dtypes
# Out:
# dem            float64
# slope          float64
# aspect         float64
# curvx          float64
# curvy          float64
# lc_grp        category
# fvc            float64
# ndbi           float64
# population     float64
# dist2river     float64
# rain           float64
# x              float64
# y              float64
# dtype: object

# %%
df_predv1.describe().columns
# Out:
# Index(['dem', 'slope', 'aspect', 'curvx', 'curvy', 'fvc', 'ndbi', 'population',
#        'dist2river', 'rain', 'x', 'y'],
#       dtype='object')

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('numerical_preprocessing',
#                                  Pipeline(steps=[('functiontransformer',
#                                                   FunctionTransformer(func=<function convert_float64 at 0x7c098d083d90>)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['dem', 'slope', 'aspect', 'curvx', 'curvy',
#                                   'fvc', 'ndbi', 'population', 'dist2river',
#                                   'rain', 'x', 'y']),
#                                 ('categorical_preprocessing',
#                                  Pipeline(steps=[('onehotencoder',
#                                                   OneHotEncoder())]),
#                                  ['lc_grp'])])

# %%
X_ds = ds[ds.columns[:-1]].reset_index(drop=True)
X_predv1 = df_predv1[df_predv1.y<27.85].reset_index(drop=True)
X_local_predv1 = preprocessor.fit(X_train).transform(X_predv1)

# %%
y_hat_mc_predv1 = np.array([balancedbatch_model(X_local_predv1) for _ in range(2000)])

# %%
MC_pred_meanv1 = np.mean(y_hat_mc_predv1, axis=0).squeeze()
MC_pred_stdv1 = np.std(y_hat_mc_predv1, axis=0).squeeze()

# %%
y_hat_simple_mcv1 = pd.DataFrame({'MC_pred_mean': MC_pred_meanv1, 'MC_pred_std': MC_pred_stdv1})
y_hat_simple_mcv1.head()
# Out:
#        pred
# 0  0.999319
# 1  0.999480
# 2  0.999448
# 3  0.999487
# 4  0.999480

# %% [markdown]
# ## Continue of uncertainty analysis

# %%
y_hat_simple_mcv1['x'] = X_predv1.x.values
y_hat_simple_mcv1['y'] = X_predv1.y.values
# y_hat_simple_mc_gpd = gpd.GeoDataFrame(
#     y_hat_simple_mc, geometry=gpd.points_from_xy(y_hat_simple_mc.x, y_hat_simple_mc.y), crs="EPSG:4269"
#     )
# y_hat_simple_mc_gpd.head()

# %% [markdown]
# # Visualize predictions in new areas

# %%
f = open("google_map_api.txt", "r")
GOOGLE_API_KEY = f.read()
f.close()

# %%
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 700,560

# %%
# Location PINELLAS COUNTY    Latitude  27.90268000    Longitude  -82.73955000
lat, lon = 27.90268000, -82.73955000

# %%
import os
api_key = GOOGLE_API_KEY

# %%
from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool

from bokeh.transform import linear_cmap
from bokeh.palettes import Plasma256
from bokeh.models import ColorBar

# %%
def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng,
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Pinellas County',
             width=bokeh_width, height=bokeh_height)
    show(p)
    return p

# %%
p = plot(lat, lon)
# Out:
#   <div id="a70869ea-808c-4daa-8c82-33fbb7e5d03d" data-root-id="p1002" style="display: contents;"></div>

# %%
# Read the shapefile
flood_img2polygon = gpd.read_file('/content/drive/MyDrive/social_media_based_model/adds_data_run_model070424/flooding_add1.shp')

# Function to extract x and y coordinates from the geometries
def extract_coords(geometry):
    if geometry.geom_type == 'Polygon':
        exterior_coords = geometry.exterior.coords.xy
        return list(exterior_coords[0]), list(exterior_coords[1])
    elif geometry.geom_type == 'MultiPolygon':
        xs, ys = [], []
        for polygon in geometry:
            exterior_coords = polygon.exterior.coords.xy
            xs.append(list(exterior_coords[0]))
            ys.append(list(exterior_coords[1]))
        return xs, ys

# Extract coordinates for all polygons
polygon_xs, polygon_ys = [], []
for geom in flood_img2polygon.geometry:
    xs, ys = extract_coords(geom)
    polygon_xs.append(xs)
    polygon_ys.append(ys)

# Prepare the data for ColumnDataSource
flood_img2polygon['polygon_xs'] = polygon_xs
flood_img2polygon['polygon_ys'] = polygon_ys

# %%
def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng,
                               map_type=map_type, zoom=zoom)
    # the tools are defined below:
    hover = HoverTool(
        tooltips = [
            ('mean flooding probability', '@MC_pred_mean'),
            ('std of mc samples', '@MC_pred_std')
        ]
    )
    # below we replaced 'hover' (the default hover tool),
    # by our custom hover tool
    p = gmap(api_key, gmap_options, title='Monte Carlo Dropout to Measure Flood Prediction Uncertainty',
             width=bokeh_width, height=bokeh_height,
             tools=[hover, 'reset', 'wheel_zoom', 'pan'])
    source = ColumnDataSource(y_hat_simple_mcv1[y_hat_simple_mcv1.y<27.85])

    mapper = linear_cmap('MC_pred_mean', Plasma256[::-1], 0., 1.)
    # print(mapper)
    # we use the mapper for the color of the circles
    center = p.scatter('x', 'y', size='radius', alpha=0.7,
                      color=mapper, source=source)
    # and we add a color scale to see which values the colors
    # correspond to
    color_bar = ColorBar(color_mapper=mapper['transform'],
                         location=(0,0))
    p.add_layout(color_bar, 'right')

    # Add polygon layer
    flood_img = ColumnDataSource(data=dict(
        polygon_xs=flood_img2polygon.polygon_xs,
        polygon_ys=flood_img2polygon.polygon_ys,
    ))

    p.patches('polygon_xs', 'polygon_ys', source=flood_img, fill_color='cyan', fill_alpha=0.3, line_color='navy')

    show(p)
    return p

p = plot(lat, lon, map_type='roadmap', zoom=10)
# Out:
#   <div id="d3ca1cec-faf0-4748-9d4e-93d48eaa8a19" data-root-id="p1062" style="display: contents;"></div>
